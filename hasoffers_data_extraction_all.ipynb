# %%
import datetime
from urllib.request import urlopen
import json
from pandas.io.json import json_normalize
import pandas as pd

# %%
join_url='https://hsbcconnect.api.hasoffers.com/Apiv3/json?api_key=9c37200b30ac14cd329929f527ef03464a8d2efccec52765a1259df344f7b9c6&Target=Affiliate_Report&Method=getConversions&fields[]=Stat.conversion_status&fields[]=Stat.offer_id&&fields[]=Stat.year&fields[]=Stat.week&fields[]=Stat.user_agent&fields[]=Stat.source&fields[]=Stat.session_ip&fields[]=Stat.session_datetime&fields[]=Stat.refer&fields[]=Stat.pixel_refer&fields[]=Stat.offer_url_id&fields[]=Stat.offer_id&fields[]=Stat.month&fields[]=Stat.is_adjustment&fields[]=Stat.ip&fields[]=Stat.affiliate_info5&fields[]=Stat.affiliate_info4&fields[]=Stat.affiliate_info3&fields[]=Stat.affiliate_info2&fields[]=PayoutGroup.name&fields[]=PayoutGroup.id&fields[]=OfferUrl.preview_url&fields[]=Country.name&fields[]=ConversionsMobile.windows_aid_sha1&fields[]=ConversionsMobile.windows_aid_md5&fields[]=ConversionsMobile.windows_aid&fields[]=ConversionsMobile.user_id&fields[]=ConversionsMobile.unknown_id&fields[]=ConversionsMobile.mobile_carrier&fields[]=ConversionsMobile.mac_address_sha1&fields[]=ConversionsMobile.mac_address_md5&fields[]=ConversionsMobile.mac_address&fields[]=ConversionsMobile.ios_ifa_md5&fields[]=ConversionsMobile.google_aid_sha1&fields[]=ConversionsMobile.google_aid_md5&fields[]=ConversionsMobile.ios_ifa&fields[]=ConversionsMobile.ios_ifa_sha1&fields[]=ConversionsMobile.google_aid&fields[]=ConversionsMobile.device_id_sha1&fields[]=ConversionsMobile.device_id_md5&fields[]=ConversionsMobile.device_model&fields[]=ConversionsMobile.device_os&fields[]=ConversionsMobile.device_os_version&fields[]=ConversionsMobile.ios_ifv&fields[]=ConversionsMobile.device_id&fields[]=ConversionsMobile.android_id_sha1&fields[]=ConversionsMobile.android_id_md5&fields[]=ConversionsMobile.android_id&fields[]=ConversionMeta.note&fields[]=Browser.id&fields[]=ConversionsMobile.device_brand&fields[]=ConversionsMobile.odin&fields[]=Browser.display_name&fields[]=OfferUrl.name&fields[]=OfferUrl.id&fields[]=Stat.id&fields[]=Stat.sale_amount&fields[]=Goal.name&fields[]=Stat.approved_payout&fields[]=Stat.affiliate_info1&fields[]=Stat.ad_id&fields[]=Stat.hour&fields[]=Stat.goal_id&fields[]=Offer.name&fields[]=Stat.date&fields[]=Stat.datetime&fields[]=Stat.currency&filters[Stat.date][conditional]=GREATER_THAN_OR_EQUAL_TO&filters[Stat.date][values]=2017-07-01&fields[]=ConversionsMobile.affiliate_click_id&limit=50000'

# %%
join_url
# Out:
# 'https://hsbcconnect.api.hasoffers.com/Apiv3/json?api_key=9c37200b30ac14cd329929f527ef03464a8d2efccec52765a1259df344f7b9c6&Target=Affiliate_Report&Method=getConversions&fields[]=Stat.conversion_status&fields[]=Stat.offer_id&&fields[]=Stat.year&fields[]=Stat.week&fields[]=Stat.user_agent&fields[]=Stat.source&fields[]=Stat.session_ip&fields[]=Stat.session_datetime&fields[]=Stat.refer&fields[]=Stat.pixel_refer&fields[]=Stat.offer_url_id&fields[]=Stat.offer_id&fields[]=Stat.month&fields[]=Stat.is_adjustment&fields[]=Stat.ip&fields[]=Stat.affiliate_info5&fields[]=Stat.affiliate_info4&fields[]=Stat.affiliate_info3&fields[]=Stat.affiliate_info2&fields[]=PayoutGroup.name&fields[]=PayoutGroup.id&fields[]=OfferUrl.preview_url&fields[]=Country.name&fields[]=ConversionsMobile.windows_aid_sha1&fields[]=ConversionsMobile.windows_aid_md5&fields[]=ConversionsMobile.windows_aid&fields[]=ConversionsMobile.user_id&fields[]=ConversionsMobile.unknown_id&fields[]=ConversionsMobile.mobile_carrier&fields[]=
# ...

# %%
url=urlopen(join_url).read()

# %%
url_json=json.loads(url)

# %%
hsbc_data=url_json['response']['data']['data']

# %%
hasoffers_hsbc_conv=pd.DataFrame.from_dict(json_normalize(hsbc_data), orient='columns')

# %%
hasoffers_hsbc_conv=hasoffers_hsbc_conv.rename(columns=lambda x: x.replace('.', '_'))

# %%
hasoffers_hsbc_conv['api_instance']= 'hasoffer_hsbc'

# %%
hasoffers_hsbc_conv
# Out:
#      Browser_display_name Browser_id ConversionMeta_note  \
# 0                 Android          8                None
# 1                 Android          8                None
# 2           iPhone / iPod          7                None
# 3                   Opera          5                None
# 4                 Firefox          2                None
# 5                 Android          8                None
# 6           iPhone / iPod          7                None
# 7                  Chrome          3                None
# 8                  Chrome          3                None
# 9                  Chrome          3                None
# 10                 Chrome          3                None
# 11                   iPad         14                None
# 12                   iPad         14                None
# 13                Android          8                None
# 14      Internet Explorer          1                None
# ...

# %%
join_url2='https://groupmconnect.api.hasoffers.com/Apiv3/json?api_key=baa591ec5ab34a54554065f10c02663005dd5d61d4304cf84aa4e9ea999fd46e&Target=Affiliate_Report&Method=getConversions&fields[]=Stat.conversion_status&fields[]=Stat.offer_id&&fields[]=Stat.year&fields[]=Stat.week&fields[]=Stat.user_agent&fields[]=Stat.source&fields[]=Stat.session_ip&fields[]=Stat.session_datetime&fields[]=Stat.refer&fields[]=Stat.pixel_refer&fields[]=Stat.offer_url_id&fields[]=Stat.offer_id&fields[]=Stat.month&fields[]=Stat.is_adjustment&fields[]=Stat.ip&fields[]=Stat.affiliate_info5&fields[]=Stat.affiliate_info4&fields[]=Stat.affiliate_info3&fields[]=Stat.affiliate_info2&fields[]=PayoutGroup.name&fields[]=PayoutGroup.id&fields[]=OfferUrl.preview_url&fields[]=Country.name&fields[]=ConversionsMobile.windows_aid_sha1&fields[]=ConversionsMobile.windows_aid_md5&fields[]=ConversionsMobile.windows_aid&fields[]=ConversionsMobile.user_id&fields[]=ConversionsMobile.unknown_id&fields[]=ConversionsMobile.mobile_carrier&fields[]=ConversionsMobile.mac_address_sha1&fields[]=ConversionsMobile.mac_address_md5&fields[]=ConversionsMobile.mac_address&fields[]=ConversionsMobile.ios_ifa_md5&fields[]=ConversionsMobile.google_aid_sha1&fields[]=ConversionsMobile.google_aid_md5&fields[]=ConversionsMobile.ios_ifa&fields[]=ConversionsMobile.ios_ifa_sha1&fields[]=ConversionsMobile.google_aid&fields[]=ConversionsMobile.device_id_sha1&fields[]=ConversionsMobile.device_id_md5&fields[]=ConversionsMobile.device_model&fields[]=ConversionsMobile.device_os&fields[]=ConversionsMobile.device_os_version&fields[]=ConversionsMobile.ios_ifv&fields[]=ConversionsMobile.device_id&fields[]=ConversionsMobile.android_id_sha1&fields[]=ConversionsMobile.android_id_md5&fields[]=ConversionsMobile.android_id&fields[]=ConversionMeta.note&fields[]=Browser.id&fields[]=ConversionsMobile.device_brand&fields[]=ConversionsMobile.odin&fields[]=Browser.display_name&fields[]=OfferUrl.name&fields[]=OfferUrl.id&fields[]=Stat.id&fields[]=Stat.sale_amount&fields[]=Goal.name&fields[]=Stat.approved_payout&fields[]=Stat.affiliate_info1&fields[]=Stat.ad_id&fields[]=Stat.hour&fields[]=Stat.goal_id&fields[]=Offer.name&fields[]=Stat.date&fields[]=Stat.datetime&fields[]=Stat.currency&filters[Stat.date][conditional]=GREATER_THAN_OR_EQUAL_TO&filters[Stat.date][values]=2017-07-01&fields[]=ConversionsMobile.affiliate_click_id&limit=50000'

# %%
url2=urlopen(join_url2).read()

# %%
url_json2=json.loads(url2)

# %%
amex_data=url_json2['response']['data']['data']

# %%
hasoffers_amex_conv=pd.DataFrame.from_dict(json_normalize(amex_data), orient='columns')

# %%
hasoffers_amex_conv=hasoffers_amex_conv.rename(columns=lambda x: x.replace('.', '_'))

# %%
hasoffers_amex_conv['api_instance']= 'hasoffer_amex'

# %%
hasoffers_amex_conv
# Out:
#     Browser_display_name Browser_id ConversionMeta_note  \
# 0                Android          8
# 1                Firefox          2
# 2                Android          8
# 3                Android          8
# 4          iPhone / iPod          7
# 5          iPhone / iPod          7
# 6                 Chrome          3
# 7      Internet Explorer          1
# 8                 Chrome          3
# 9
# 10         iPhone / iPod          7
# 11
# 12               Firefox          2
# 13                Chrome          3
# 14                Chrome          3
# 15                Chrome          3
# 16                Chrome          3
# 17               Android          8
# 18               Firefox          2
# 19                Chrome          3
# 20     Internet Explorer          1
# 21
# 22         iPhone / iPod          7
# 23               Android          8
# 24                 Opera          5
# 25                Chrome          3
# 26                Chrome          3
# ...

# %%
hasoffers_conv=pd.concat([hasoffers_hsbc_conv,hasoffers_amex_conv], axis=0,ignore_index= True).drop_duplicates()

# %%
hasoffers_conv['Browser_display_name']=hasoffers_conv['Browser_display_name'].astype(str)
hasoffers_conv['Browser_id']=hasoffers_conv['Browser_id'].astype(str)
hasoffers_conv['ConversionMeta_note']=hasoffers_conv['ConversionMeta_note'].astype(str)
hasoffers_conv['ConversionsMobile_affiliate_click_id']=hasoffers_conv['ConversionsMobile_affiliate_click_id'].astype(str)
hasoffers_conv['ConversionsMobile_android_id']=hasoffers_conv['ConversionsMobile_android_id'].astype(str)
hasoffers_conv['ConversionsMobile_android_id_md5']=hasoffers_conv['ConversionsMobile_android_id_md5'].astype(str)
hasoffers_conv['ConversionsMobile_android_id_sha1']=hasoffers_conv['ConversionsMobile_android_id_sha1'].astype(str)
hasoffers_conv['ConversionsMobile_device_brand']=hasoffers_conv['ConversionsMobile_device_brand'].astype(str)
hasoffers_conv['ConversionsMobile_device_id']=hasoffers_conv['ConversionsMobile_device_id'].astype(str)
hasoffers_conv['ConversionsMobile_device_id_md5']=hasoffers_conv['ConversionsMobile_device_id_md5'].astype(str)
hasoffers_conv['ConversionsMobile_device_id_sha1']=hasoffers_conv['ConversionsMobile_device_id_sha1'].astype(str)
hasoffers_conv['ConversionsMobile_device_model']=hasoffers_conv['ConversionsMobile_device_model'].astype(str)
hasoffers_conv['ConversionsMobile_device_os']=hasoffers_conv['ConversionsMobile_device_os'].astype(str)
hasoffers_conv['ConversionsMobile_device_os_version']=hasoffers_conv['ConversionsMobile_device_os_version'].astype(str)
hasoffers_conv['ConversionsMobile_google_aid']=hasoffers_conv['ConversionsMobile_google_aid'].astype(str)
hasoffers_conv['ConversionsMobile_google_aid_md5']=hasoffers_conv['ConversionsMobile_google_aid_md5'].astype(str)
hasoffers_conv['ConversionsMobile_google_aid_sha1']=hasoffers_conv['ConversionsMobile_google_aid_sha1'].astype(str)
hasoffers_conv['ConversionsMobile_ios_ifa']=hasoffers_conv['ConversionsMobile_ios_ifa'].astype(str)
hasoffers_conv['ConversionsMobile_ios_ifa_md5']=hasoffers_conv['ConversionsMobile_ios_ifa_md5'].astype(str)
hasoffers_conv['ConversionsMobile_ios_ifa_sha1']=hasoffers_conv['ConversionsMobile_ios_ifa_sha1'].astype(str)
hasoffers_conv['ConversionsMobile_ios_ifv']=hasoffers_conv['ConversionsMobile_ios_ifv'].astype(str)
hasoffers_conv['ConversionsMobile_mac_address']=hasoffers_conv['ConversionsMobile_mac_address'].astype(str)
hasoffers_conv['ConversionsMobile_mac_address_md5']=hasoffers_conv['ConversionsMobile_mac_address_md5'].astype(str)
hasoffers_conv['ConversionsMobile_mac_address_sha1']=hasoffers_conv['ConversionsMobile_mac_address_sha1'].astype(str)
hasoffers_conv['ConversionsMobile_mobile_carrier']=hasoffers_conv['ConversionsMobile_mobile_carrier'].astype(str)
hasoffers_conv['ConversionsMobile_odin']=hasoffers_conv['ConversionsMobile_odin'].astype(str)
hasoffers_conv['ConversionsMobile_unknown_id']=hasoffers_conv['ConversionsMobile_unknown_id'].astype(str)
hasoffers_conv['ConversionsMobile_user_id']=hasoffers_conv['ConversionsMobile_user_id'].astype(str)
hasoffers_conv['ConversionsMobile_windows_aid']=hasoffers_conv['ConversionsMobile_windows_aid'].astype(str)
hasoffers_conv['ConversionsMobile_windows_aid_md5']=hasoffers_conv['ConversionsMobile_windows_aid_md5'].astype(str)
hasoffers_conv['ConversionsMobile_windows_aid_sha1']=hasoffers_conv['ConversionsMobile_windows_aid_sha1'].astype(str)
hasoffers_conv['Country_name']=hasoffers_conv['Country_name'].astype(str)
hasoffers_conv['Goal_name']=hasoffers_conv['Goal_name'].astype(str)
hasoffers_conv['Offer_name']=hasoffers_conv['Offer_name'].astype(str)
hasoffers_conv['OfferUrl_id']=hasoffers_conv['OfferUrl_id'].astype(int)
hasoffers_conv['OfferUrl_name']=hasoffers_conv['OfferUrl_name'].astype(str)
hasoffers_conv['OfferUrl_preview_url']=hasoffers_conv['OfferUrl_preview_url'].astype(str)
hasoffers_conv['PayoutGroup_id']=hasoffers_conv['PayoutGroup_id'].astype(int)
hasoffers_conv['PayoutGroup_name']=hasoffers_conv['PayoutGroup_name'].astype(str)
hasoffers_conv['Stat_ad_id']=hasoffers_conv['Stat_ad_id'].astype(str)
hasoffers_conv['Stat_affiliate_info1']=hasoffers_conv['Stat_affiliate_info1'].astype(str)
hasoffers_conv['Stat_affiliate_info2']=hasoffers_conv['Stat_affiliate_info2'].astype(str)
hasoffers_conv['Stat_affiliate_info3']=hasoffers_conv['Stat_affiliate_info3'].astype(str)
hasoffers_conv['Stat_affiliate_info4']=hasoffers_conv['Stat_affiliate_info4'].astype(str)
hasoffers_conv['Stat_affiliate_info5']=hasoffers_conv['Stat_affiliate_info5'].astype(str)
hasoffers_conv['Stat_approved_payout']=hasoffers_conv['Stat_approved_payout'].astype(float)
hasoffers_conv['Stat_conversion_status']=hasoffers_conv['Stat_conversion_status'].astype(str)
hasoffers_conv['Stat_currency']=hasoffers_conv['Stat_currency'].astype(str)
hasoffers_conv['Stat_date']=hasoffers_conv['Stat_date'].astype(str)
hasoffers_conv['Stat_datetime']=hasoffers_conv['Stat_datetime'].astype(str)
hasoffers_conv['Stat_goal_id']=hasoffers_conv['Stat_goal_id'].astype(int)
hasoffers_conv['Stat_hour']=hasoffers_conv['Stat_hour'].astype(int)
hasoffers_conv['Stat_id']=hasoffers_conv['Stat_id'].astype(int)
hasoffers_conv['Stat_ip']=hasoffers_conv['Stat_ip'].astype(str)
hasoffers_conv['Stat_is_adjustment']=hasoffers_conv['Stat_is_adjustment'].astype(int)
hasoffers_conv['Stat_month']=hasoffers_conv['Stat_month'].astype(int)
hasoffers_conv['Stat_offer_id']=hasoffers_conv['Stat_offer_id'].astype(int)
hasoffers_conv['Stat_offer_url_id']=hasoffers_conv['Stat_offer_url_id'].astype(int)
hasoffers_conv['Stat_pixel_refer']=hasoffers_conv['Stat_pixel_refer'].astype(str)
hasoffers_conv['Stat_raw_approved_payout']=hasoffers_conv['Stat_raw_approved_payout'].astype(float)
hasoffers_conv['Stat_refer']=hasoffers_conv['Stat_refer'].astype(str)
hasoffers_conv['Stat_raw_approved_payout']=hasoffers_conv['Stat_raw_approved_payout'].astype(float)
hasoffers_conv['Stat_refer']=hasoffers_conv['Stat_refer'].astype(str)
hasoffers_conv['Stat_session_datetime']=hasoffers_conv['Stat_session_datetime'].astype(str)
hasoffers_conv['Stat_session_ip']=hasoffers_conv['Stat_session_ip'].astype(str)
hasoffers_conv['Stat_source']=hasoffers_conv['Stat_source'].astype(str)
hasoffers_conv['Stat_user_agent']=hasoffers_conv['Stat_user_agent'].astype(str)
hasoffers_conv['Stat_week']=hasoffers_conv['Stat_week'].astype(int)
hasoffers_conv['Stat_year']=hasoffers_conv['Stat_year'].astype(int)
# hasoffers_conv['Stat.sale_amount']=hasoffers_conv['Stat.sale_amount'].astype(str)

# %%
hasoffers_conv
# Out:
#      Browser_display_name Browser_id ConversionMeta_note  \
# 0                 Android          8                None
# 1                 Android          8                None
# 2           iPhone / iPod          7                None
# 3                   Opera          5                None
# 4                 Firefox          2                None
# 5                 Android          8                None
# 6           iPhone / iPod          7                None
# 7                  Chrome          3                None
# 8                  Chrome          3                None
# 9                  Chrome          3                None
# 10                 Chrome          3                None
# 11                   iPad         14                None
# 12                   iPad         14                None
# 13                Android          8                None
# 14      Internet Explorer          1                None
# ...

# %%
hasoffers_conv.drop_duplicates(subset=['Stat_id','Stat_ad_id'],keep='last').reset_index(drop=True)
# Out:
#      Browser_display_name Browser_id ConversionMeta_note  \
# 0                 Android          8                None
# 1                 Android          8                None
# 2           iPhone / iPod          7                None
# 3                   Opera          5                None
# 4                 Firefox          2                None
# 5                 Android          8                None
# 6           iPhone / iPod          7                None
# 7                  Chrome          3                None
# 8                  Chrome          3                None
# 9                  Chrome          3                None
# 10                 Chrome          3                None
# 11                   iPad         14                None
# 12                   iPad         14                None
# 13                Android          8                None
# 14      Internet Explorer          1                None
# ...

# %%
# hasoffers_conv=hasoffers_conv=hasoffers_conv.sort_values(['Stat_datetime'], ascending=True)

# %%
# hasoffers_conv=hasoffers_conv.drop_duplicates(subset=['Stat_ad_id'],keep="last").reset_index(drop=True)

# %%
hasoffers_conv.to_csv('hasoffers_all.csv', sep=',', encoding='utf-8',index=None)

# %%
import boto
import boto.s3
import sys
from boto.s3.key import Key

AWS_ACCESS_KEY_ID = 'AKIAI2G6TBD7YHYBRNRQ'
AWS_SECRET_ACCESS_KEY = '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'

bucket_name = 'hasoffers-conversions'
conn = boto.connect_s3(AWS_ACCESS_KEY_ID,
        AWS_SECRET_ACCESS_KEY)


bucket = conn.create_bucket(bucket_name,
    location=boto.s3.connection.Location.DEFAULT)

testfile = "hasoffers_all.csv"
print ('Uploading %s to Amazon S3 bucket %s' % \
   (testfile, bucket_name))

def percent_cb(complete, total):
    sys.stdout.write('.')
    sys.stdout.flush()


k = Key(bucket)
k.key = 'hasoffers_conversions'
k.set_contents_from_filename(testfile,cb=percent_cb, num_cb=10)
# Out:
# Uploading hasoffers_all.csv to Amazon S3 bucket hasoffers-conversions
# ..........
# 1748462

# %%
import psycopg2
con=psycopg2.connect(dbname= 'dev', host='ratecity.cvjjsart4teb.us-east-1.redshift.amazonaws.com', 
port= '5439', user= 'indu', password= 'Abcd@1234')

# %%
sql_1='''
truncate hasoffers_conversions;
'''
cur = con.cursor()
cur.execute(sql_1)

# %%
sql_2='''COPY hasoffers_conversions
FROM 's3://hasoffers-conversions/hasoffers_conversions'
CREDENTIALS 'aws_access_key_id=AKIAI2G6TBD7YHYBRNRQ;aws_secret_access_key=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'
REGION AS 'us-east-1' FILLRECORD EMPTYASNULL CSV ACCEPTINVCHARS TRUNCATECOLUMNS IGNOREHEADER AS 1;commit'''

# %%
cur = con.cursor()
cur.execute(sql_2)
